# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/Shareddrives/슈퍼학부생 CREW/staganv2/cyclegan_code
# Out:
# /content/drive/Shareddrives/슈퍼학부생 CREW/staganv2/cyclegan_code

# %%
! python main.py --mode 'test' --train_continue 'on' --lr 2e-4 --batch_size 4 --num_epoch 100 --ny 256 --nx 256 --nch 3 --nker 64 --wgt_cycle 1e2 --wgt_ident 5e-1 --network 'CycleGAN' --data_dir 'datasets/spring' --ckpt_dir 'checkpoint' --log_dir 'log' --result_dir 'result'
# Out:
# mode: test
# learning rate: 2.0000e-04
# batch size: 4
# number of epoch: 100
# task: cyclegan
# opts: ['direction', array([0.])]
# network: CycleGAN
# learning type: plain
# data dir: datasets/spring
# ckpt dir: checkpoint
# log dir: log
# result dir: result
# device: cuda
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# TEST A: BATCH 0001 / 0032 |
# TEST A: BATCH 0002 / 0032 |
# TEST A: BATCH 0003 / 0032 |
# TEST A: BATCH 0004 / 0032 |
# TEST A: BATCH 0005 / 0032 |
# TEST A: BATCH 0006 / 0032 |
# TEST A: BATCH 0007 / 0032 |
# TEST A: BATCH 0008 / 0032 |
# TEST A: BATCH 0009 / 0032 |
# TEST A: BATCH 0010 / 0032 |
# TEST A: BATCH 0011 / 0032 |
# TEST A: BATCH 0012 / 0032 |
# TEST A: BATCH 0013 / 0032 |
# TEST A: BATCH 0014 / 0032 |
# TEST A: BATCH 0015 / 0032 |
# TEST A: BATCH 0016 / 0032 |
# TEST A: BATCH 0017 / 0032 |
# TEST A: BATCH 0018 / 0032 |
# TEST A: BATCH 0019 / 0032 |
# ...

# %%
! python main.py --mode 'test' --train_continue 'on' --lr 2e-4 --batch_size 4 --num_epoch 100 --ny 256 --nx 256 --nch 3 --nker 64 --wgt_cycle 1e2 --wgt_ident 5e-1 --network 'CycleGAN' --data_dir 'datasets/spring' --ckpt_dir 'checkpoint_aihub' --log_dir 'log_aihub' --result_dir 'result_aihub'
# Out:
# mode: test
# learning rate: 2.0000e-04
# batch size: 4
# number of epoch: 100
# task: cyclegan
# opts: ['direction', array([0.])]
# network: CycleGAN
# learning type: plain
# data dir: datasets/spring
# ckpt dir: checkpoint_aihub
# log dir: log_aihub
# result dir: result_aihub
# device: cuda
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# TEST A: BATCH 0001 / 0032 |
# TEST A: BATCH 0002 / 0032 |
# TEST A: BATCH 0003 / 0032 |
# TEST A: BATCH 0004 / 0032 |
# TEST A: BATCH 0005 / 0032 |
# TEST A: BATCH 0006 / 0032 |
# TEST A: BATCH 0007 / 0032 |
# TEST A: BATCH 0008 / 0032 |
# TEST A: BATCH 0009 / 0032 |
# TEST A: BATCH 0010 / 0032 |
# TEST A: BATCH 0011 / 0032 |
# TEST A: BATCH 0012 / 0032 |
# TEST A: BATCH 0013 / 0032 |
# TEST A: BATCH 0014 / 0032 |
# TEST A: BATCH 0015 / 0032 |
# TEST A: BATCH 0016 / 0032 |
# TEST A: BATCH 0017 / 0032 |
# TEST A: BATCH 0018 / 0032 |
# TEST A: BATCH 0019 / 0032 |
# ...

# %%
! python main.py --mode 'test' --train_continue 'on' --lr 2e-4 --batch_size 4 --num_epoch 100 --ny 256 --nx 256 --nch 3 --nker 64 --wgt_cycle 1e2 --wgt_ident 5e-1 --network 'CycleGAN' --data_dir 'datasets/spring' --ckpt_dir 'checkpoint_final' --log_dir 'log_final' --result_dir 'result_final'
# Out:
# mode: test
# learning rate: 2.0000e-04
# batch size: 4
# number of epoch: 100
# task: cyclegan
# opts: ['direction', array([0.])]
# network: CycleGAN
# learning type: plain
# data dir: datasets/spring
# ckpt dir: checkpoint_final
# log dir: log_final
# result dir: result_final
# device: cuda
# initialize network with normal
# initialize network with normal
# initialize network with normal
# initialize network with normal
# TEST A: BATCH 0001 / 0032 |
# TEST A: BATCH 0002 / 0032 |
# TEST A: BATCH 0003 / 0032 |
# TEST A: BATCH 0004 / 0032 |
# TEST A: BATCH 0005 / 0032 |
# TEST A: BATCH 0006 / 0032 |
# TEST A: BATCH 0007 / 0032 |
# TEST A: BATCH 0008 / 0032 |
# TEST A: BATCH 0009 / 0032 |
# TEST A: BATCH 0010 / 0032 |
# TEST A: BATCH 0011 / 0032 |
# TEST A: BATCH 0012 / 0032 |
# TEST A: BATCH 0013 / 0032 |
# TEST A: BATCH 0014 / 0032 |
# TEST A: BATCH 0015 / 0032 |
# TEST A: BATCH 0016 / 0032 |
# TEST A: BATCH 0017 / 0032 |
# TEST A: BATCH 0018 / 0032 |
# TEST A: BATCH 0019 / 0032 |
# ...

# %%
import zipfile
import os
import shutil

# %%
import os


# file_list = os.listdir('./spring_5000/no1')
# des = 'spring_5000/no'
# for f in file_list:
#     shutil.move(f,des)
# file_list
# 이동할 파일들을 닮을 배열 객체
mov_files = []

# Files List Create - TEXT 파일을 제외한 파일들이 이동대상 파일
for file in file_list:
	if(file.endswith(".txt")):
		print("text File : " + file)
	else:
		print("Else File : " + file)
		mov_files.append(file)

# Move Files
for movfi in mov_files:
	print('Move File : ' + oPath + ' 에 있는 ' + movfi + ' ----- &gt; ' + nPath + '로 이동하였습니다.')
	shutil.move(oPath + '\\' + movfi, nPath + '\\' + movfi)

# %%
# !ls
# Out:
# dataset.py		layer.py  README.md    util.py
# display_results.py	main.py   run_main.sh  yorkbeom.ipynb
# filter_spring_5000.egg	model.py  train.py

# %%
# zipfile.ZipFile('spring_until2500').extractall('./spring_5000')
# zipfile.ZipFile('filter_spring_5000.zip').extractall()
! tar -xvf filter_spring_5000.tar
# Out:
# testA/face-1.png
# testA/face-11.png
# testA/face-4.png
# testA/face-5.png
# testA/face-9.png
# testB/face-2.png
# testB/face-3.png
# testB/face-6.png
# testB/face-7.png
# testB/face-8.png
# trainA/face-1000.png
# trainA/face-1004.png
# trainA/face-1007.png
# trainA/face-1009.png
# trainA/face-1010.png
# trainA/face-1015.png
# trainA/face-1016.png
# trainA/face-1018.png
# trainA/face-1019.png
# trainA/face-102.png
# trainA/face-1020.png
# trainA/face-1021.png
# trainA/face-1022.png
# trainA/face-1024.png
# trainA/face-1025.png
# trainA/face-1027.png
# trainA/face-1028.png
# trainA/face-1032.png
# trainA/face-1035.png
# trainA/face-1036.png
# trainA/face-1037.png
# trainA/face-1038.png
# trainA/face-104.png
# trainA/face-1041.png
# trainA/face-1043.png
# trainA/face-1048.png
# trainA/face-105.png
# trainA/face-1050.png
# trainA/face-1051.png
# trainA/face-1054.png
# trainA/face-1055.png
# trainA/face-1057.png
# trainA/face-1058.png
# trainA/face-1059.png
# trainA/face-106.png
# ...
